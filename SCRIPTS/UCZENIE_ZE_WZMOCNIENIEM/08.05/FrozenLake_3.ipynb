# %% [markdown]
# UWAGA: Wczytaj do Colab plik **frozen_lake_slippery.py** lub **frozen_lake.py** (intrukcja w pliku **COLAB_instrukcja.pdf**)

# %% [markdown]
# # **FrozenLake 3**

# %%
from frozen_lake import FrozenLakeEnv
#from frozen_lake_slippery import FrozenLakeEnv
import numpy as np

env = FrozenLakeEnv()

# %% [markdown]
# Chcemy napisać funkcję, która korzystając z określonych wartości zwrótów ***V(s)*** (dla wszystkich stanów ***s***) zwróci wartości ***Q(s,a)*** dla konkretnego stanu ***s*** i dla wszystkich akcji **a** możliwych do wykonania w stanie **s**.

# %% [markdown]
# Załóżmy, że mamy dane ***V(s)*** takie jak na rysunku poniżej:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Wartości zwrotów ***V(s)*** dla każdego stanu zapiszemy w tablicy:

# %%
V = np.array([0.16807,0.2401,0.343,0.2401,0.2401,0.,0.49,0.,0.343,0.49,0.7,0.,0.,0.7,1.,0.])
print(V)

# %% [markdown]
# Funkcję zdefiniujemy korzystając z formuły:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Polecenie 1 (do uzupełnienia)

# %% [markdown]
# Funkcja dla danego ***s*** i znanego ***V*** ma zwracać wartości zwrotów **dla czterech akcji** możliwych do wykonanania w stanie ***s***. Czyli może wyglądać tak (**UZUPEŁNIJ DEFINICJĘ FUNKCJI**):

# %%
def Q_from_V(env, V, s, gamma=0.99):
    Q = np.zeros(env.nA)

    for action in range(env.nA):
        
        #DO UZUPEŁNIENIA
    
    return Q

# %% [markdown]
# OBJAŚNIENIE: Argumenty funkcji (oprócz ***V*** i ***s***) to zmienna ***env*** związana ze środowiskiem ***FrozenLake*** i wartość ***gamma***, która występuje w powyższym wzorze. ***Q*** zdefiniowane w pierwszej linijce definicji to **4 elementowa tablica złożona z zer** (**env.nA** to ilość akcji, które można wykonać w środowisku określonym przez **env**). W pętli **for** mają być wyliczone **wartości zwrotów dla każdej z czterech akcji 0,1,2,3**. Wartości tę mają być zapisane w tablicy ***Q***. Funkcja zwróci tę tablicę.

# %% [markdown]
# # Polecenie 2 (do uzupełnienia)

# %% [markdown]
# Przetestuj działanie funkcji ***Q_from_V*** dla domyślnej wartości **gamma=0,99**

# %% [markdown]
# Wartości zwrotów dla 4 akcji w stanie ***s=0***:

# %%
#zwrot dla akcji 0
#zwrot dla akcji 1
#zwrot dla akcji 2
#zwrot dla akcji 3

# %% [markdown]
# Wartości zwrotów dla 4 akcji w stanie ***s=8***:

# %%
#zwrot dla akcji 0
#zwrot dla akcji 1
#zwrot dla akcji 2
#zwrot dla akcji 3

# %% [markdown]
# Wartości zwrotów dla 4 akcji w stanie ***s=15***:

# %%
#zwrot dla akcji 0
#zwrot dla akcji 1
#zwrot dla akcji 2
#zwrot dla akcji 3

# %% [markdown]
# Przetestuj działanie funkcji ***Q_from_V*** dla mniejszej wartości **gamma=0.1**

# %% [markdown]
# Wartości zwrotów dla 4 akcji w stanie ***s=0***:

# %%
#zwrot dla akcji 0
#zwrot dla akcji 1
#zwrot dla akcji 2
#zwrot dla akcji 3

# %% [markdown]
# Wartości zwrotów dla 4 akcji w stanie ***s=8***:

# %%
#zwrot dla akcji 0
#zwrot dla akcji 1
#zwrot dla akcji 2
#zwrot dla akcji 3

# %% [markdown]
# Wartości zwrotów dla 4 akcji w stanie ***s=15***:

# %%
#zwrot dla akcji 0
#zwrot dla akcji 1
#zwrot dla akcji 2
#zwrot dla akcji 3

# %% [markdown]
# # Polecenie 3 (do uzupełnienia)

# %% [markdown]
# Jaki wpływ na wyniki miała zmiana wartości parametru **gamma** i dlaczego taki?

# %% [markdown]
# WPISZ ODPOWIEDŹ:
